# %%
from ultralytics import YOLO
import cv2
import json
import os

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# To check if the sub-object(child_bbox) is inside the object(parent_bbox)
def is_within(parent_bbox, child_bbox):
    px1, py1, px2, py2 = parent_bbox
    cx1, cy1, cx2, cy2 = child_bbox
    return px1 <= cx1 <= px2 and px1 <= cx2 <= px2 and py1 <= cy1 <= py2 and py1 <= cy2 <= py2


# Detects objects and find object and sub-object hierarchy
def detect_hierarchy(frame, model):
    results = model.predict(source=frame, device='cpu', conf=0.5, imgsz=640)
    detections = results[0].boxes.xyxy.cpu().numpy()  # bounding boxes (x1, y1, x2, y2)
    confidences = results[0].boxes.conf.cpu().numpy()  # confidence scores
    class_ids = results[0].boxes.cls.cpu().numpy()  # class IDs

    objects = []
    hierarchy = []

    # Process detections
    for i, bbox in enumerate(detections):
        x1, y1, x2, y2 = map(int, bbox)
        objects.append({
            "id": i,
            "bbox": [x1, y1, x2, y2],
            "class_id": int(class_ids[i]),
            "confidence": float(confidences[i])
        })

    # hierarchy logic based on bounding box 
    for obj in objects:
        is_subobject = False
        for potential_parent in objects:
            if obj["id"] != potential_parent["id"] and is_within(potential_parent["bbox"], obj["bbox"]):
                # Object has sub-object
                hierarchy.append({
                    "object": potential_parent["class_id"],
                    "id": potential_parent["id"],
                    "bbox": potential_parent["bbox"],
                    "subobject": {
                        "object": obj["class_id"],
                        "id": obj["id"],
                        "bbox": obj["bbox"]
                    }
                })
                is_subobject = True
                break

        if not is_subobject:
            # Object has no sub-object
            hierarchy.append({
                "object": obj["class_id"],
                "id": obj["id"],
                "bbox": obj["bbox"],
                "subobject": None
            })

    return hierarchy
# save output to a json file
def save_json(data, output_path):
    with open(output_path, 'w') as f:
        json.dump(data, f, indent=4)

def crop_and_save_subobjects(frame, hierarchy, output_dir, frame_count):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for obj in hierarchy:
        if obj["subobject"]:
            sub_x1, sub_y1, sub_x2, sub_y2 = obj["subobject"]["bbox"]
            subobject_crop = frame[sub_y1:sub_y2, sub_x1:sub_x2]

            if subobject_crop.size > 0:
                subobject_path = os.path.join(output_dir, f"frame_{frame_count}_subobject_{obj['subobject']['id']}.png")
                cv2.imwrite(subobject_path, subobject_crop)

def process_video_with_cropping(video_path, output_json_path, output_video_path, subobject_dir):
    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    # Output video writer
    out = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*'XVID'), fps, (frame_width, frame_height))
    frame_count = 0
    all_hierarchies = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        hierarchy = detect_hierarchy(frame, model)
        all_hierarchies.append({"frame": frame_count, "detections": hierarchy})
        # Draw detections on frame
        for obj in hierarchy:
            x1, y1, x2, y2 = obj["bbox"]
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f'ID: {obj["id"]}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            if obj["subobject"]:
                sub_x1, sub_y1, sub_x2, sub_y2 = obj["subobject"]["bbox"]
                cv2.rectangle(frame, (sub_x1, sub_y1), (sub_x2, sub_y2), (255, 0, 0), 2)
                cv2.putText(frame, f'Sub-ID: {obj["subobject"]["id"]}', (sub_x1, sub_y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

        # Crop and save subobjects
        crop_and_save_subobjects(frame, hierarchy, subobject_dir, frame_count)
        out.write(frame)

    # Save JSON output
    save_json(all_hierarchies, output_json_path)

    # Release resources
    cap.release()
    out.release()
   


# Paths for input and output
video_path = 'test_video. mp4'
output_json_path = 'output_json. json'
output_video_path = 'output_video. avi'
subobject_dir = 'subobjects/'

# Run the process
process_video_with_cropping(video_path, output_json_path, output_video_path, subobject_dir)
# Out:
# 0: 384x640 1 person, 1 tie, 1 laptop, 84.9ms
# Speed: 3.1ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 82.6ms
# Speed: 2.5ms preprocess, 82.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 69.8ms
# Speed: 3.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 67.7ms
# Speed: 3.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 70.3ms
# Speed: 4.0ms preprocess, 70.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 71.6ms
# Speed: 3.0ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 78.1ms
# Speed: 3.9ms preprocess, 78.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 82.2ms
# Speed: 3.0ms preprocess, 82.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 80.9ms
# Speed: 3.5ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 82.9ms
# Speed: 4.0ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 72.7ms
# Speed: 3.0ms preprocess, 72.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 71.2ms
# Speed: 3.0ms preprocess, 71.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 71.4ms
# Speed: 3.0ms preprocess, 71.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 73.2ms
# Speed: 3.6ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 85.8ms
# Speed: 4.0ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 88.7ms
# Speed: 4.0ms preprocess, 88.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 70.4ms
# Speed: 4.0ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 146.8ms
# Speed: 4.0ms preprocess, 146.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 77.1ms
# Speed: 4.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 92.9ms
# Speed: 1.1ms preprocess, 92.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 82.7ms
# Speed: 4.0ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 80.8ms
# Speed: 3.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 95.9ms
# Speed: 4.0ms preprocess, 95.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 72.8ms
# Speed: 3.0ms preprocess, 72.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 69.4ms
# Speed: 3.0ms preprocess, 69.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 95.4ms
# Speed: 3.0ms preprocess, 95.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 93.0ms
# Speed: 4.0ms preprocess, 93.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 88.0ms
# Speed: 7.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 89.0ms
# Speed: 4.6ms preprocess, 89.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 82.6ms
# Speed: 4.0ms preprocess, 82.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 107.5ms
# Speed: 3.0ms preprocess, 107.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 77.9ms
# Speed: 4.5ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 77.4ms
# Speed: 4.0ms preprocess, 77.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 81.3ms
# Speed: 3.0ms preprocess, 81.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 83.0ms
# Speed: 3.4ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 80.6ms
# Speed: 3.0ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 84.9ms
# Speed: 3.9ms preprocess, 84.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 88.9ms
# Speed: 3.0ms preprocess, 88.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 82.2ms
# Speed: 3.7ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 74.1ms
# Speed: 3.0ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 75.9ms
# Speed: 3.0ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 75.2ms
# Speed: 3.0ms preprocess, 75.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 76.2ms
# Speed: 4.0ms preprocess, 76.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 82.8ms
# Speed: 3.0ms preprocess, 82.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 71.6ms
# Speed: 3.5ms preprocess, 71.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 91.8ms
# Speed: 3.0ms preprocess, 91.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 72.3ms
# Speed: 3.0ms preprocess, 72.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 81.6ms
# Speed: 3.5ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 75.4ms
# Speed: 5.0ms preprocess, 75.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 75.0ms
# Speed: 3.7ms preprocess, 75.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 87.1ms
# Speed: 3.8ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 89.5ms
# Speed: 3.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 77.7ms
# Speed: 3.0ms preprocess, 77.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 77.3ms
# Speed: 4.0ms preprocess, 77.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 101.4ms
# Speed: 4.0ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 76.0ms
# Speed: 3.4ms preprocess, 76.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 77.3ms
# Speed: 2.5ms preprocess, 77.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 84.8ms
# Speed: 4.7ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 82.0ms
# Speed: 6.8ms preprocess, 82.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 74.3ms
# Speed: 3.5ms preprocess, 74.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 68.7ms
# Speed: 4.0ms preprocess, 68.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 70.7ms
# Speed: 4.0ms preprocess, 70.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 87.5ms
# Speed: 3.1ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 113.1ms
# Speed: 3.1ms preprocess, 113.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 104.3ms
# Speed: 5.0ms preprocess, 104.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 92.9ms
# Speed: 3.1ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 81.7ms
# Speed: 3.0ms preprocess, 81.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 107.5ms
# Speed: 3.0ms preprocess, 107.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 177.0ms
# Speed: 3.0ms preprocess, 177.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 80.1ms
# Speed: 3.0ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 75.3ms
# Speed: 3.0ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 70.6ms
# Speed: 3.4ms preprocess, 70.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 88.3ms
# Speed: 3.0ms preprocess, 88.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 101.5ms
# Speed: 4.0ms preprocess, 101.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 94.5ms
# Speed: 3.0ms preprocess, 94.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 87.9ms
# Speed: 2.7ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 82.7ms
# Speed: 3.9ms preprocess, 82.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 85.3ms
# Speed: 4.0ms preprocess, 85.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 78.8ms
# Speed: 3.0ms preprocess, 78.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 77.1ms
# Speed: 3.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 81.5ms
# Speed: 4.1ms preprocess, 81.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 103.8ms
# Speed: 3.0ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 75.1ms
# Speed: 3.0ms preprocess, 75.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 90.6ms
# Speed: 4.0ms preprocess, 90.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 90.6ms
# Speed: 5.0ms preprocess, 90.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 70.7ms
# Speed: 4.2ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 68.5ms
# Speed: 3.1ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 73.7ms
# Speed: 3.0ms preprocess, 73.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 85.7ms
# Speed: 3.0ms preprocess, 85.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 107.2ms
# Speed: 2.8ms preprocess, 107.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 85.8ms
# Speed: 5.3ms preprocess, 85.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 101.6ms
# Speed: 3.4ms preprocess, 101.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 76.7ms
# Speed: 4.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 80.7ms
# Speed: 4.0ms preprocess, 80.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 74.9ms
# Speed: 3.0ms preprocess, 74.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 127.0ms
# Speed: 3.8ms preprocess, 127.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 1 tie, 1 laptop, 97.7ms
# Speed: 3.9ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 71.6ms
# Speed: 3.0ms preprocess, 71.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 71.3ms
# Speed: 3.6ms preprocess, 71.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 67.5ms
# Speed: 4.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 68.3ms
# Speed: 3.0ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 73.6ms
# Speed: 3.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 94.2ms
# Speed: 3.3ms preprocess, 94.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 84.3ms
# Speed: 3.0ms preprocess, 84.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 97.9ms
# Speed: 5.0ms preprocess, 97.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 85.7ms
# Speed: 4.2ms preprocess, 85.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 88.4ms
# Speed: 3.0ms preprocess, 88.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 93.4ms
# Speed: 4.1ms preprocess, 93.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 116.0ms
# Speed: 4.3ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 97.1ms
# Speed: 4.0ms preprocess, 97.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 88.7ms
# Speed: 3.0ms preprocess, 88.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 110.0ms
# Speed: 3.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 81.9ms
# Speed: 3.4ms preprocess, 81.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 78.8ms
# Speed: 4.1ms preprocess, 78.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 72.2ms
# Speed: 3.0ms preprocess, 72.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 75.3ms
# Speed: 3.0ms preprocess, 75.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 70.6ms
# Speed: 4.0ms preprocess, 70.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 67.5ms
# Speed: 3.2ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 114.3ms
# Speed: 4.2ms preprocess, 114.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 98.5ms
# Speed: 4.0ms preprocess, 98.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 91.1ms
# Speed: 4.2ms preprocess, 91.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 72.6ms
# Speed: 3.0ms preprocess, 72.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 103.6ms
# Speed: 4.6ms preprocess, 103.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 92.6ms
# Speed: 4.6ms preprocess, 92.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 77.6ms
# Speed: 3.5ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 laptop, 91.9ms
# Speed: 3.0ms preprocess, 91.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 94.8ms
# Speed: 3.7ms preprocess, 94.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 laptop, 72.7ms
# Speed: 2.5ms preprocess, 72.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 79.1ms
# Speed: 3.9ms preprocess, 79.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 92.1ms
# Speed: 3.0ms preprocess, 92.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 160.1ms
# Speed: 3.0ms preprocess, 160.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 98.5ms
# Speed: 4.3ms preprocess, 98.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 92.6ms
# Speed: 3.0ms preprocess, 92.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 77.2ms
# Speed: 2.4ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 74.5ms
# Speed: 4.0ms preprocess, 74.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 89.5ms
# Speed: 3.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 69.7ms
# Speed: 3.0ms preprocess, 69.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 78.4ms
# Speed: 3.8ms preprocess, 78.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 84.1ms
# Speed: 3.0ms preprocess, 84.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 laptop, 106.0ms
# Speed: 3.1ms preprocess, 106.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 197.2ms
# Speed: 4.5ms preprocess, 197.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 93.5ms
# Speed: 3.1ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 77.6ms
# Speed: 5.1ms preprocess, 77.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 laptop, 120.1ms
# Speed: 4.0ms preprocess, 120.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 97.3ms
# Speed: 4.0ms preprocess, 97.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 90.9ms
# Speed: 4.1ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 90.3ms
# Speed: 3.0ms preprocess, 90.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 88.8ms
# Speed: 4.0ms preprocess, 88.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 125.8ms
# Speed: 3.9ms preprocess, 125.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 101.1ms
# Speed: 3.8ms preprocess, 101.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 100.5ms
# Speed: 3.5ms preprocess, 100.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 118.2ms
# Speed: 3.0ms preprocess, 118.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 84.1ms
# Speed: 3.0ms preprocess, 84.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 120.0ms
# Speed: 4.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 99.4ms
# Speed: 4.0ms preprocess, 99.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 86.9ms
# Speed: 3.7ms preprocess, 86.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 85.7ms
# Speed: 4.1ms preprocess, 85.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 88.6ms
# Speed: 3.5ms preprocess, 88.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 92.6ms
# Speed: 3.8ms preprocess, 92.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 98.6ms
# Speed: 3.0ms preprocess, 98.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 104.9ms
# Speed: 4.0ms preprocess, 104.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 104.2ms
# Speed: 5.6ms preprocess, 104.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 96.5ms
# Speed: 4.3ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 91.4ms
# Speed: 4.0ms preprocess, 91.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 89.5ms
# Speed: 4.0ms preprocess, 89.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 136.6ms
# Speed: 4.6ms preprocess, 136.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 117.4ms
# Speed: 4.0ms preprocess, 117.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 93.8ms
# Speed: 3.0ms preprocess, 93.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 79.4ms
# Speed: 5.0ms preprocess, 79.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 98.2ms
# Speed: 4.3ms preprocess, 98.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 93.5ms
# Speed: 4.6ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 94.4ms
# Speed: 3.2ms preprocess, 94.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 142.8ms
# Speed: 18.4ms preprocess, 142.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 106.4ms
# Speed: 4.8ms preprocess, 106.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 92.3ms
# Speed: 4.0ms preprocess, 92.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 109.2ms
# Speed: 1.8ms preprocess, 109.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 207.4ms
# Speed: 4.2ms preprocess, 207.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 118.2ms
# Speed: 12.1ms preprocess, 118.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 80.4ms
# Speed: 9.0ms preprocess, 80.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 77.4ms
# Speed: 3.5ms preprocess, 77.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 91.0ms
# Speed: 3.5ms preprocess, 91.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 106.1ms
# Speed: 2.6ms preprocess, 106.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 99.1ms
# Speed: 4.5ms preprocess, 99.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 153.1ms
# Speed: 0.0ms preprocess, 153.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 107.6ms
# Speed: 5.3ms preprocess, 107.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 108.1ms
# Speed: 3.0ms preprocess, 108.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 102.4ms
# Speed: 4.0ms preprocess, 102.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 102.2ms
# Speed: 5.0ms preprocess, 102.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 108.9ms
# Speed: 3.6ms preprocess, 108.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 117.7ms
# Speed: 4.5ms preprocess, 117.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 100.6ms
# Speed: 5.1ms preprocess, 100.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 87.4ms
# Speed: 3.3ms preprocess, 87.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 87.5ms
# Speed: 4.3ms preprocess, 87.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 114.7ms
# Speed: 2.2ms preprocess, 114.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 98.2ms
# Speed: 4.8ms preprocess, 98.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 113.2ms
# Speed: 4.8ms preprocess, 113.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 116.2ms
# Speed: 6.8ms preprocess, 116.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 106.5ms
# Speed: 2.0ms preprocess, 106.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 104.7ms
# Speed: 4.9ms preprocess, 104.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 117.7ms
# Speed: 4.0ms preprocess, 117.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 106.6ms
# Speed: 5.3ms preprocess, 106.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 133.8ms
# Speed: 29.9ms preprocess, 133.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 92.5ms
# Speed: 5.2ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 81.6ms
# Speed: 4.2ms preprocess, 81.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 88.2ms
# Speed: 5.3ms preprocess, 88.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 91.7ms
# Speed: 4.7ms preprocess, 91.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 89.8ms
# Speed: 4.4ms preprocess, 89.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 112.3ms
# Speed: 4.5ms preprocess, 112.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 100.0ms
# Speed: 5.4ms preprocess, 100.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 96.8ms
# Speed: 0.8ms preprocess, 96.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 118.6ms
# Speed: 7.0ms preprocess, 118.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 98.9ms
# Speed: 5.0ms preprocess, 98.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 130.1ms
# Speed: 6.5ms preprocess, 130.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 132.9ms
# Speed: 3.5ms preprocess, 132.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 137.5ms
# Speed: 8.9ms preprocess, 137.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 128.5ms
# Speed: 4.9ms preprocess, 128.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 88.2ms
# Speed: 4.2ms preprocess, 88.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 100.1ms
# Speed: 5.4ms preprocess, 100.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 99.5ms
# Speed: 1.8ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 92.1ms
# Speed: 4.0ms preprocess, 92.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 97.1ms
# Speed: 3.1ms preprocess, 97.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 125.1ms
# Speed: 5.4ms preprocess, 125.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 94.7ms
# Speed: 4.0ms preprocess, 94.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 92.8ms
# Speed: 3.7ms preprocess, 92.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 89.0ms
# Speed: 5.2ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 205.5ms
# Speed: 9.7ms preprocess, 205.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 113.9ms
# Speed: 2.5ms preprocess, 113.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 110.0ms
# Speed: 4.0ms preprocess, 110.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 90.4ms
# Speed: 4.1ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 93.9ms
# Speed: 4.1ms preprocess, 93.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 110.0ms
# Speed: 4.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 103.9ms
# Speed: 5.2ms preprocess, 103.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 120.3ms
# Speed: 5.6ms preprocess, 120.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 92.5ms
# Speed: 5.0ms preprocess, 92.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 99.0ms
# Speed: 5.5ms preprocess, 99.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 88.9ms
# Speed: 5.1ms preprocess, 88.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 102.9ms
# Speed: 4.5ms preprocess, 102.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 113.8ms
# Speed: 5.4ms preprocess, 113.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 107.3ms
# Speed: 6.2ms preprocess, 107.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 96.5ms
# Speed: 4.9ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 95.1ms
# Speed: 4.1ms preprocess, 95.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 82.8ms
# Speed: 4.0ms preprocess, 82.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 92.3ms
# Speed: 4.3ms preprocess, 92.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 107.1ms
# Speed: 6.9ms preprocess, 107.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 90.2ms
# Speed: 4.1ms preprocess, 90.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 92.5ms
# Speed: 5.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 223.2ms
# Speed: 3.7ms preprocess, 223.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 105.5ms
# Speed: 4.9ms preprocess, 105.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 108.4ms
# Speed: 4.2ms preprocess, 108.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 1 laptop, 97.6ms
# Speed: 5.5ms preprocess, 97.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 139.2ms
# Speed: 3.4ms preprocess, 139.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 131.6ms
# Speed: 4.1ms preprocess, 131.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 108.4ms
# Speed: 3.0ms preprocess, 108.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 91.3ms
# Speed: 4.9ms preprocess, 91.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 94.1ms
# Speed: 4.9ms preprocess, 94.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 83.8ms
# Speed: 3.2ms preprocess, 83.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 95.3ms
# Speed: 3.0ms preprocess, 95.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 104.9ms
# Speed: 3.5ms preprocess, 104.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 119.9ms
# Speed: 4.0ms preprocess, 119.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
